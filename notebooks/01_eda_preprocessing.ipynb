# %% [markdown]
# # Task 1: EDA and Preprocessing
# This notebook runs the same reproducible Task 1 pipeline implemented in `src/preprocess.py`.

# %%
import sys
from pathlib import Path
sys.path.append(str(Path('..').resolve()))
from src.preprocess import load_complaints, run_eda, filter_and_clean

# %%
input_path = Path('../data/raw/complaints.csv.zip')
df = load_complaints(input_path)
df.shape

# %%
eda_df = run_eda(df, '../figures')
eda_df[['has_narrative', 'narrative_word_count']].describe()

# %%
cleaned = filter_and_clean(df)
cleaned['product_category'].value_counts()

# %%
output_path = Path('../data/processed/filtered_complaints.csv')
output_path.parent.mkdir(parents=True, exist_ok=True)
cleaned.to_csv(output_path, index=False)
output_path
